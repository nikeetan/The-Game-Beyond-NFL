# %%
import pandas as pd


df = pd.read_csv('data/imputed_data.csv')

df['Position'] = df['Position'].astype('category').cat.codes


df.drop(columns=['Name','Stat URL','Year','College','conf_abbr'], axis=1, inplace=True)
df
# Out:
#       Position  Round  Pick  Height  Weight  40 Yard Dash  Bench Press  \
# 0           14      6   204    74.0   238.0          4.64        24.00
# 1           21      4   104    71.0   179.0          4.51        14.59
# 2            5      0     0    76.0   296.0          5.31        19.00
# 3            3      4   103    76.0   270.0          4.80        24.48
# 4           19      7   242    73.0   210.0          4.58        17.00
# ...        ...    ...   ...     ...     ...           ...          ...
# 3679         0      6   190    75.0   303.0          5.14        25.26
# 3680        17      1     1    70.0   204.0          4.65        18.86
# 3681         5      3    70    75.0   294.0          4.92        24.00
# 3682         6      3    77    74.0   250.0          4.43        22.00
# 3683         5      4   123    75.0   304.0          5.10        29.53
#
#       Vertical Jump  Broad Jump  3 Cone Drill  ...  rec_yds_per_rec  rec_td  \
# ...

# %%
import seaborn as sns
from IPython.core.display import display, HTML

import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr = df.corr()

# Generate a heatmap
plt.figure(figsize=(22, 22))
ax = sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap')
ax.xaxis.set_ticks_position('top')
plt.xticks(rotation=90)


plt.show()
# Out:
# /var/folders/zp/8ykdjlwd1qjdfz83znprmqp00000gn/T/ipykernel_25813/3956821325.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
